# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
pip uninstall notebook jupyterlab ipykernel ipython -y
# Out:
# Found existing installation: notebook 7.4.5
# Uninstalling notebook-7.4.5:
#   Successfully uninstalled notebook-7.4.5
# Found existing installation: jupyterlab 4.4.6
# Uninstalling jupyterlab-4.4.6:
#   Successfully uninstalled jupyterlab-4.4.6
# Found existing installation: ipykernel 6.29.5
# Uninstalling ipykernel-6.29.5:
#   Successfully uninstalled ipykernel-6.29.5
# Found existing installation: ipython 9.1.0
# Uninstalling ipython-9.1.0:
#   Successfully uninstalled ipython-9.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install notebook ipykernel ipython
# Out:
# Collecting notebook
#   Using cached notebook-7.4.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipykernel in c:\users\daegu\anaconda3\lib\site-packages (6.30.1)
# Requirement already satisfied: ipython in c:\users\daegu\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\daegu\anaconda3\lib\site-packages (from notebook) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\daegu\anaconda3\lib\site-packages (from notebook) (2.27.3)
# Collecting jupyterlab<4.5,>=4.4.5 (from notebook)
#   Using cached jupyterlab-4.4.6-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\daegu\anaconda3\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\daegu\anaconda3\lib\site-packages (from notebook) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.2)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (72.1.0)
# Requirement already satisfied: certifi in c:\users\daegu\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\daegu\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (1.0.9)
# Requirement already satisfied: idna in c:\users\daegu\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\daegu\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\daegu\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\daegu\anaconda3\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\daegu\anaconda3\lib\site-packages (from ipykernel) (1.8.11)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\daegu\anaconda3\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\daegu\anaconda3\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\daegu\anaconda3\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: colorama in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\daegu\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\daegu\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\daegu\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\daegu\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\daegu\anaconda3\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\daegu\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\daegu\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Requirement already satisfied: uri-template in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\daegu\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\daegu\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\daegu\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\daegu\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\daegu\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\daegu\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\daegu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\daegu\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\daegu\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\daegu\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\daegu\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\daegu\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\daegu\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\daegu\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython) (0.2.2)
# Using cached notebook-7.4.5-py3-none-any.whl (14.3 MB)
# Using cached jupyterlab-4.4.6-py3-none-any.whl (12.3 MB)
# Installing collected packages: jupyterlab, notebook
#
#    ---------------------------------------- 0/2 [jupyterlab]
#    ---------------------------------------- 0/2 [jupyterlab]
#    ---------------------------------------- 0/2 [jupyterlab]
#    ---------------------------------------- 0/2 [jupyterlab]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    -------------------- ------------------- 1/2 [notebook]
#    ---------------------------------------- 2/2 [notebook]
#
# Successfully installed jupyterlab-4.4.6 notebook-7.4.5
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
# 선
plt.plot(dataset_1['x'], dataset_1['y'])
# Out:
# <div id='fa784420-5dcc-48ba-8bd0-3cb40e56d5b7'></div>

# %%
# 점
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure()
# Out:
# <div id='4f43da3a-8dba-4e4e-a336-d1b793041462'></div>

# %%
pip install matplotlib seaborn plotly ipympl
# Out:
# Requirement already satisfied: matplotlib in c:\users\daegu\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\daegu\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\daegu\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: ipympl in c:\users\daegu\anaconda3\lib\site-packages (0.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\daegu\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\daegu\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\daegu\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: ipython<10 in c:\users\daegu\anaconda3\lib\site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\daegu\anaconda3\lib\site-packages (from ipympl) (8.1.5)
# Requirement already satisfied: traitlets<6 in c:\users\daegu\anaconda3\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.1.6)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\daegu\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.2.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\daegu\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\daegu\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\daegu\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.13)
# Requirement already satisfied: wcwidth in c:\users\daegu\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\daegu\anaconda3\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daegu\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\daegu\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\daegu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\daegu\anaconda3\lib\site-packages (from stack_data->ipython<10->ipympl) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)
# Out:
# <div id='0c761d8e-e3e7-4a37-b4c8-794c61810cf2'></div>

# %%
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill') 

fig

# %%
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(
    x=tips['total_bill'], 
    y=tips['tip'],    
    s=tips['size'] * 10,    
    c=tips['sex_color'],
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill']) 
ax.set_title('Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], kde=False) 
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# <div id='7ec023fc-6b89-4fd4-9710-893a8e592d85'></div>
# C:\Users\daegu\AppData\Local\Temp\ipykernel_5852\1691838747.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist=False) 
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# <div id='ed385e2e-2898-47a1-8b0a-62c45b4602d9'></div>
# C:\Users\daegu\AppData\Local\Temp\ipykernel_5852\2536088683.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
hist_den_rug, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], rug=True) 
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')

# %%
ax = plt.subplots() 
ax = sns.countplot('day', data=tips) 
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')

# %% [markdown]
# # 다변량 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# <div id='01d9b4f2-a5e0-4a24-9b7b-268632b96dd8'></div>
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <div id='04e405e8-6d6e-448e-a5b7-c30fefc98ad9'></div>
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex") 
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)

# %%
kde, ax = plt.subplots() 
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], 
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# <div id='a7148d55-b40f-41e2-b60c-bcca28a959bb'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 kde, ax = plt.subplots()
# ----> 2 ax = sns.kdeplot(data=tips['total_bill'],
#       3                  data2=tips['tip'],
#       4                  shade=True)
#       5 ax.set_title('Kernel Density Plot of Total Bill and Tip')
#       6 ax.set_xlabel('Total Bill')
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1596, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1594 if "data2" in kwargs:
#    1595     msg = "`data2` has been removed (replaced by `y`); please update your code."
# -> 1596     raise TypeError(msg)
#    1598 # Handle deprecation of `vertical`
#    1599 vertical = kwargs.pop("vertical", None)
#
# TypeError: `data2` has been removed (replaced by `y`); please update your code.

# %%
ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# <div id='397977ca-1111-4d36-83eb-849c0f504528'></div>
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# <div id='5b2aa59d-9280-4b1c-a574-e486fb0c587a'></div>
# C:\Users\daegu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\daegu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\daegu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)

# %%
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True) 
plt.show()

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False) 
plt.show()
# Out:
# <div id='7a85da14-b5da-413f-b787-0a11ab346231'></div>

# %%
fig = sns.pairplot(tips, hue='sex')

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10}) 
plt.show()
# Out:
# <div id='758ca1f1-42c8-41bc-894e-b923e7231623'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\regression.py:651, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
#     644     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
#     645     scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
#    (...)    649     scatter_kws=scatter_kws, line_kws=line_kws,
#     650 )
# --> 651 facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     652 facets.set_axis_labels(x, y)
#     654 # Add a legend
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:825, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     822     kwargs["data"] = data_ijk
#     824     # Draw the plot
# --> 825     self._facet_plot(func, ax, args, kwargs)
#     827 # For axis labels, prefer to use positional args for backcompat
#     828 # but also extract the x/y kwargs and use if no corresponding arg
#     829 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# File ~\anaconda3\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\regression.py:381, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     379 # Draw the constituent plots
#     380 if self.scatter:
# --> 381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
#     384     self.lineplot(ax, line_kws)
#
# File ~\anaconda3\Lib\site-packages\seaborn\regression.py:411, in _RegressionPlotter.scatterplot(self, ax, kws)
#     408         kws.setdefault("alpha", .8)
#     410     x, y = self.scatter_data
# --> 411     ax.scatter(x, y, **kws)
#     412 else:
#     413     # TODO abstraction
#     414     ci_kws = {"color": kws["color"]}
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4909, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4905 s = np.ma.ravel(s)
#    4906 if (len(s) not in (1, x.size) or
#    4907         (not np.issubdtype(s.dtype, np.floating) and
#    4908          not np.issubdtype(s.dtype, np.integer))):
# -> 4909     raise ValueError(
#    4910         "s must be a scalar, "
#    4911         "or float array-like with the same size as x and y")
#    4913 # get the original edgecolor the user passed before we normalize
#    4914 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10}) 
plt.show()

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %%
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %%
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)

# %%
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()

# %% [markdown]
# # 알아두면 좋아요
