# %% [markdown]
# # 2장

# %%
import pandas

# %%
df= pandas.read_csv('../data/gapminder.tsv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2838197940.py in <cell line: 0>()
# ----> 1 df= pandas.read_csv('../data/gapminder.tsv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/gapminder.tsv'

# %%
import pandas as pd
df= pd.read_csv('../data/gapminder.tsv')

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3810112079.py in <cell line: 0>()
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
print(type(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-499212768.py in <cell line: 0>()
# ----> 1 print(type(df))
#
# NameError: name 'df' is not defined

# %%
print(df.share)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2545088070.py in <cell line: 0>()
# ----> 1 print(df.share)
#
# NameError: name 'df' is not defined

# %%
print(df.columns)

# %%
print(df.dtypes)

# %%
print(df.into())

# %%
country_df= df['country']
print(type(country_df))
<class 'pandas.core.series.Series'>
print(country_df.head())

# %%
print(country_df.tail())

# %%
subset= df[['country', 'continent', 'year']]
print(type(subset))

# %%
print(subset.head())

# %%
print(subset.tail())

# %%
print(df.loc[0])

# %%
print(df.loc[99])

# %%
print(df.loc[-1])

# %%
number_of_rows= df.shape[0]
last_row_index= number_of_rows-1
print(df.loc[last_row_index])

# %%
print(df.tail(n=1))

# %%
print(df.loc[[0,99,999]])

# %%
subset_loc= df.loc[0]
subset_tail=df.tail(n=1)

# %%
print(type(subset_loc))
print(type(subset_tail))

# %%
print(df.iloc[1])

# %%
print(df.iloc[99])

# %%
print(df.iloc[-1])

# %%
print(df.iloc[1710])

# %%
print(df.iloc[[0,99,999]])

# %%
subset=df.loc[:,['year','pop']]
print(subset.head())

# %%
subset= df.iloc[:,[2,4,-1]]
print(subset.head())

# %%
small_range= list(range(5))
print(small_range)

# %%
print(type(small_range))

# %%
subset= df.iloc[:,small_range]
print(subset.head())

# %%
small_range= list(range(3,6))
print(small_range)

# %%
subset= df.iloc[:,small_range]
print(subset.head())

# %%
small_range= list(range(0,6,2))
subset= df.iloc[:, small_range]
print(subset.head())

# %%
subset= df.iloc[:, :3]
print(subset.head())

# %%
subset= df.iloc[:, 0:6:2]
print(subset.head())

# %%
print(df.iloc[[0,99,999],[0,3,5]])

# %%
print(df.iloc[[0,99,999],['country','lifeExp','gdpPercap']])

# %%
print(df.iloc[[10:13],['country','lifeExp','gdpPercap']])

# %%
print(df.head(n=10))

# %%
print(df.groupby('year')['lifeExp'].mean())

# %%
grouped_year_df= df.groupby('year')
print(type(grouped_year_df))

# %%
print(grouped_year_df)

# %%
grouped_year_df_lifeExp= grouped_year_df['lifeExp']
print(type(grouped_year_df_lifeExp))

# %%
mean_lifeExp_by_year= grouped_year_df_lifeExp.mean()
print(mean_lifeExp_by_year)

# %%
multi_group_var= df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
print(multi_group_var)

# %%
print(type(multi_group_var))

# %%
print(df.groupby('continent')['cuntry'].nunique())

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
global_yearly_life_expectancy= df.groupby('year')['lifeExp'].mean()
print(global_yearly_life_expectancy)

# %%
global_yearly_life_expectancy.plot()

# %% [markdown]
# # 3장

# %%
import pandas as pd
s= pd.Series(['banana',42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s= pd.Series(['Wes McKinney','Creator od Pandas'])
print(s)
# Out:
# 0         Wes McKinney
# 1    Creator od Pandas
# dtype: object

# %%
s= pd.Series(['Wes McKinney','Creator od Pandas'], index=['Person','Who'])
print(s)
# Out:
# Person         Wes McKinney
# Who       Creator od Pandas
# dtype: object

# %%
scientists= pd.DataFrame({
    'Name': ['Rosaline Franklin','William Gosset'],
    'Occupation': ['Chemist','Statistician'],
    'Born': ['1920-07-25','1876-06-13'],
    'Died': ['1958-04-16','1937-10-16'],
    'Age': [37,61]
})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists= pd.DataFrame(
    data={'Occupation': ['Chemist','Statistician'],
          'Born': ['1920-07-25','1876-06-13'],
          'Died': ['1958-04-16','1937-10-16'],
          'Age': [37,61]},
    index=['Rasaline Franklin','William Gosset'],
    columns= ['Occupation','Born','Age','Died']
)
print(scientists)
# Out:
#                      Occupation        Born  Age        Died
# Rasaline Franklin       Chemist  1920-07-25   37  1958-04-16
# William Gosset     Statistician  1876-06-13   61  1937-10-16

# %%
from collections import OrderedDict

scientists= pd.DataFrame(OrderedDict([
    ('Name',['Rosaline Franklin','William Gosset']),
    ('Occupation',['Chemist','Statistian']),
    ('Born',['1920-07-25','1876-06-13']),
    ('Died',['1958-04-16','1937-10-16']),
    ('Age',[37,61])
])
)
print(scientists)
# Out:
#                 Name  Occupation        Born        Died  Age
# 0  Rosaline Franklin     Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistian  1876-06-13  1937-10-16   61

# %%
scientists= pd.DataFrame(
    data={'Occupation': ['Chemist','Statistician'],
          'Born': ['1920-07-25','1876-06-13'],
          'Died': ['1958-04-16','1937-10-16'],
          'Age': [37,61]},
    index=['Rasaline Franklin','William Gosset'],
    columns= ['Occupation','Born','Age','Died'])

# %%
first_row= scientists.loc['William Gosset']
print(type(first_row))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(first_row)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Age                     61
# Died            1937-10-16
# Name: William Gosset, dtype: object

# %%
print(first_row.index)
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
print(first_row.values)
# Out:
# ['Statistician' '1876-06-13' np.int64(61) '1937-10-16']

# %%
print(first_row.keys())
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
print(first_row.index[0])
# Out:
# Occupation

# %%
print(first_row.keys()[0])
# Out:
# Occupation

# %%
ages= scientists['Age']
print(ages)
# Out:
# Rasaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
print(ages.mean())
# Out:
# 49.0

# %%
print(ages.min())
# Out:
# 37

# %%
print(ages.max())
# Out:
# 61

# %%
print(ages.std())
# Out:
# 16.97056274847714

# %%
scientsts= pd.read_csv('../data/scientists.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-559248185.py in <cell line: 0>()
# ----> 1 scientsts= pd.read_csv('../data/scientists.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/scientists.csv'

# %%
ages= scientists['Age']
print(ages.max())
# Out:
# 61

# %%
print(ages.mean())
# Out:
# 49.0

# %%
print(ages[ages > ages.mean()])
# Out:
# William Gosset    61
# Name: Age, dtype: int64

# %%
print(ages>ages.mean())

# %%
print(type(ages>ages.mean()))

# %%
manual_bool_values= [True, True, False, False, True, True, False, True]
print(ages[manual_bool_values])

# %%
print(ages+ages)

# %%
print(ages*ages)

# %%
print(ages+100)

# %%
print(ages*2)

# %%
print(pd.Series([1,100]))

# %%
print(ages+pd.Series([1,100]))

# %%
rev_ages= ages.sort_index(ascending=False)
print(rev_ages)

# %%
print(ages*2)

# %%
print(ages+rev_ages)

# %%
print(scientists[scienstists['Age']>scientists['Age'].mean()])

# %%
Print(scientists.loc[[True, True, False, True]])

# %%
print(scientists*2)
# Out:
#                                  Occupation                  Born  Age  \
# Rasaline Franklin            ChemistChemist  1920-07-251920-07-25   74
# William Gosset     StatisticianStatistician  1876-06-131876-06-13  122
#
#                                    Died
# Rasaline Franklin  1958-04-161958-04-16
# William Gosset     1937-10-161937-10-16

# %%
print(scientists['Born'].dtype)
# Out:
# object

# %%
print(scientists['Died'].dtype)
# Out:
# object

# %%
born_datatime= pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1466922581.py in <cell line: 0>()
#       1 born_datatime= pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
# ----> 2 print(born_datetime)
#
# NameError: name 'born_datetime' is not defined

# %%
died_datatime= pd.to_datetime(scientists['Died'],format='%Y-%m-%d')
print(died_datetime)

# %%
scientists['born_dt'],scientists['died_dt']= (born_datetime,died_time)
print(scientists.head())

# %%
print(scientists.shape)
# Out:
# (2, 4)

# %%
scientists['age_days_dt']= (scientists['died_dt']-scientists['born_dt'])
print(scientists)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'died_dt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3838216187.py in <cell line: 0>()
# ----> 1 scientists['age_days_dt']= (scientists['died_dt']-scientists['born_dt'])
#       2 print(scientists)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'died_dt'

# %%
print(scientists['Age'])
# Out:
# Rasaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
import random

randoom.seed(42)
random.shuffle(scientists['Age'])
print(scientists['Age'])

# %%
print(scientists.columns)

# %%
scientists_dropped= scientists.drop(['Age'], axis=1)
print(scientists_dropped.columns)

# %%
names= scientists['Name']
names.to_pickle('../output/scientists_names_series.pickle')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3502773335.py in <cell line: 0>()
# ----> 1 names= scientists['Name']
#       2 names.to_pickle('../output/scientists_names_series.pickle')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Name'

# %%
scientists.to_pickle('../output/scientists_df.pickle')

# %%
scientist_names_from_pickle= pd.read_pickle('../output/scientists_names_series.pickle')
print(scientist_names_from_pickle)

# %%
scientists_from_pickle= pd.read_pickle('../output/scientists_df.pickle')
print(scientists_from_pickle)

# %%
names.to_csv('../output/scientist_names_series.csv')
scientists.to_csv('../output/scientists_df.tsv',sep='\t')

# %% [markdown]
# # 4장

# %%
import seaborn as sns
anscombe= sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1= anscombe[anscombe['dataset']=='Ⅰ']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2473119150.py in <cell line: 0>()
# ----> 1 dataset_1= anscombe[anscombe['dataset']=='Ⅰ']
#
# NameError: name 'anscombe' is not defined

# %%
plt.plot(dataset_1['x'], dataset_1['y'])
# Out:
# <div id='b3281d42-a32f-4163-84f0-51fffb7ccc74'></div>

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_2= anscombe[anscombe['dataset']== 'Ⅱ']
dataset_3= anscombe[anscombe['dataset']== 'Ⅲ']
dataset_4= anscombe[anscombe['dataset']==  'Ⅳ']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2027699294.py in <cell line: 0>()
# ----> 1 dataset_2= anscombe[anscombe['dataset']== 'Ⅱ']
#       2 dataset_3= anscombe[anscombe['dataset']== 'Ⅲ']
#       3 dataset_4= anscombe[anscombe['dataset']==  'Ⅳ']
#
# NameError: name 'anscombe' is not defined

# %%
fig= plt.figure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2339193431.py in <cell line: 0>()
# ----> 1 fig= plt.figure()
#
# NameError: name 'plt' is not defined

# %%
axes1= fig.add_subplot(2, 2, 1)
axes2= fig.add_subplot(2, 2, 1)
axes3= fig.add_subplot(2, 2, 3)
axes4= fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

# %%
fig.suptitle("Anscombe Data")

# %%
fig.tight_layout()

# %%
tips= sns.load_dataset("tips")
print(tips.head())
print(type(tips))

# %%
fig= plt.figure()
axes1= fig.add_subplot(1, 1, 1)

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

# %%
scatter_plot= plt.figure()
axes1= scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total bill vs Tips')
axes1.set_xlabel(Total Bill')
axes1.set_ylabel('Tip')

# %%
boxplot= plt.figure()
axes1= boxplot.add_subplot(1, 1, 1)

axes1.boxplot([tips[tips['sex']== 'Female']['tip'],
               tips[tips['sex']== 'Male']['tip']]
               labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')

# %%
def recode_sex(sex):
    if sex== 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color']= tips['sex'].apply(recode_sex)

# %%
scatter_plot= plt.figure()
axes1= scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size'] * 10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

# %%
import seaborn as sns

tips= sns.load_dataset("tips")

# %%
ax= plt.subplots()
ax= sns.displot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')

# %%
ax= plt.subplots()
ax= sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

# %%
ax= plt.subplots()
ax= sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')

# %%
ax= plt.subplots()
ax= sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

# %%
ax= plt.subplots()
ax= sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Billband Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

# %%
ax= plt.subplots()
ax= sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Billband Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

# %%
joint= sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total bill and Tip', fontsize=1-, y=1.03)

# %%
hexbin= sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)

# %%
ax= plt.subplots()
ax= sns.kdeplot(data=tips['total.bill'],
                data2=tips['tip'],
                shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

# %%
ax= plt.subplots()
ax= sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time od day')
ax.set_ylabel('Average total bill')

# %%
pair_grid= sns.PairGrid(tips)
pair_grid= pair_grid.map_upper(sns.regplot)
pair_grid= pair_grid.map_lower(sns.kdeplot)
pair_grid= pair_grid.map_diag(sns.distplot, rug=True)
plt.show()

# %%
ax= plt.subplots()
ax= sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
scatter= sns.lmplot(x='total_bill', y='tip', hue='sex', fit_reg=False)

# %%
fig= sns.pairplot(tips, hue='sex')

# %%
scatter= sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                    markers=['o','x'], catter_kws={'s': tips['size']*10})

# %%
anscombe_plot= sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                          col='dataset', col_wrap=2)

# %%
facet= sns.FacetGrid(tips, col='time')
facet.map(sns.displot, 'total_bill', rug=True)

# %%
facet= sns.FacetGrid(tips, col='day', hue='sex')
facet= facet.map(plt.scatter, 'total_bill', 'tip')
facet= facet.add_legend()

# %%
ax= plt.subplots()
ax= tips['total_bill'].plot.hist()

# %%
fig, ax= plt.subplots()
ax= tips[['total_bill','tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
ax= plt.subplots()
ax= tips['tip'].plot.kde()

# %%
fig, ax= plt.subplots()
ax= tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax=plt.subplots()
ax= tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, ax=plt.subplots()
ax= tips.plot.box(ax=ax)

# %%
fig, ax= plt.subplots()
ax= sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.set_style('whitegrid')
fig, ax=plt.subplots()
ax= sns.violinplot(x='time', y='total_bill', hue='sex', data,tips, split=True)

# %%
fig=plt.figure()

seaborn_styles= ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position=idx+1
    with sns.axes_style(style):
        ax= fig.add_subplot(2,3,plot_position)
        violin= sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1908550250.py in <cell line: 0>()
# ----> 1 fig=plt.figure()
#       2
#       3 seaborn_styles= ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
#       4
#       5 for idx, style in enumerate(seaborn_styles):
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 5장

# %%
import pandas as pd

df1=pd.read_csv()

# %%
row_concat= pd.concat([df1, df2, df3])
print(row_concat)

# %%
print(row_concat.iloc[3, ])

# %%
new_row_series= pd.Series(['n1', 'n2', 'n3', 'n4'])

# %%
print(pd.concat([df1, new_row_series]))

# %%
new_row_df= pd.DataFrame([['n1', 'n2', 'n3', 'n4']], columns=['A','B','C','D'])
print(new_row_df)

# %%
print(pd.concat([df1, new_row_df]))

# %%
print(df1.append(new_row_df))

# %%
row_concat_i= pd.concat([df1, df2, df3], ignore_index=True)
print(row_concat_i)

# %%
col_concat= pd.concat([df1,df2,df3], axis=1)
print(col_concat)

# %%
print(col_concat['A'])

# %%
df1.columns=['A','B','C','D']
df2.columns=['E','F','G','H']
df3.columns=['A','C','F','H']
print(df1)
print(type(df1))

# %%
print(df2)
print(type(df2))

# %%
print(df3)
print(type(df3))

# %%
row_concat= pd.concat([df1, df2, df3])
print(row_concat)

# %%
print(pd.concat([df1, df2, df3], ignore_index=False, join='inner'))

# %%
df1.index= [0,1,2,3]
df2.index= [4,5,6,7]
df3.index= [0,2,5,7]

# %%
print(df1)

# %%
print(df2)

# %%
print(df3)

# %%
col_concat= pd.concat([df1,df2,df3], axis=1)
print(c0l_concat)

# %%
print(pd.concat([df1,df3], axis=1, join='inner'))

# %%
#p.132
person=pd

# %%
print(person)

# %%
print(site)

# %%
print(visited)

# %%
print(survet)

# %%
visited_subset= visited.loc[[0,2,6], ]

# %%
o2o_merge= site.merge(visited_subset, left_on='name', right_on='site')
print(o2o_merge)

# %%
o2o_merge= site.merge(visited, left_on='name', right_on='site')
print(o2o_merge)

# %%
ps=person.merge(survey,left_on='ident', right_on='person')
vs=visited.mrege(survey, left_on='ident', right_on='taken')

# %%
print(ps)

# %%
print(vs)

# %%
from numpy import NaN, NAN, nan
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2655062594.py in <cell line: 0>()
# ----> 1 from numpy import NaN, NAN, nan
#
# ImportError: cannot import name 'NaN' from 'numpy' (/usr/local/lib/python3.12/dist-packages/numpy/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
print(NaN== True)

# %%
print(NaN== False)

# %%
print(NnN== 0)

# %%
print(NaN== '')

# %%
print(NaN== NaN)

# %%
print(NaN== NAN)

# %%
print(nan== NAN)

# %%
import pandas as pd

# %%
print(pd.isnull(NaN))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4237652172.py in <cell line: 0>()
# ----> 1 print(pd.isnull(NaN))
#
# NameError: name 'NaN' is not defined

# %%
print(pd.isnull(nan))

# %%
print(pd.isnull(NAN))

# %%
print(pd.nomnull(NaN))

# %%
print(pd.notnull(42))

# %%
print(pd.notnull('missing'))

# %%
#140

# %%
print(visited)

# %%
print(survey)

# %%
vs= visited.merge(survey, left_on='ident, right_on='taken)
print(vs)

# %%
num_legs=pd.Series({'goat': 4, 'amoeba': nan})
print(num_legs)
print(type(num_legs))

# %%
#143
gapminder

# %%
life_exp= gapminder.groupby(['year'])['lifeExp'].mean()
print(life_exp)

# %%
print(life_exp.loc[range(2000,2010), ])

# %%
y2000= life_exp[life_exp.index > 2000]
print(y2000)

# %%
#145
ebola

# %%
print(ebola.count())

# %%
num_rows= ebola.shape[0]
num_missing= num_rows - ebola.count()
print(num_missing)

# %%
import numpy as np

# %%
print(np.count_nonzero(ebola.isnull()))

# %%
print(np.count_nonzero(ebola['Cases_Guinea'].isnull()))

# %%
print(ebola.Cases_Guinea.value_counts(dropna=False).head())

# %%
print(ebola.fillna(0).iloc[0:10, 0:5])

# %%
print(ebola.fillna(method='ffill').iloc[0:10, 0:5])

# %%
print(ebola.fillna(method='bfill').iloc[0:10, 0:5])

# %%
print(ebola.interpolate().iloc[0:10, 0:5])

# %%
print(ebola.shape)

# %%
ebola_dropna= ebola.dropna()
print(ebola_dropna.shape)

# %%
print(ebola_dropna)

# %% [markdown]
# # 7장

# %%
import pandas as pd
pew=pd.read

# %%
print(pew.iloc[:, 0:6])

# %%
pew_long= pd.melt(pew, id_vars='religion')
print(pew_long.head())

# %%
pew_long= pd.melt(pew, id_vars='religion', var_name='income', value_name='count')
print(pew_long.head())

# %%
#156
billboard= pd.read
print(billboard.iloc[0:5, 0:16])

# %%
billboard_long= pd.melt(billbaoard, id_vars=['year','artist','track','time',
                                             'date.entered'], var_name='week', value_name='rating')
print(billboard_long.head())

# %%
# 158
ebola
print(ebola.columns)

# %%
print(ebola.iloc[:5, [0,1,2,3,10,11]])

# %%
ebola_long= pd.melt(ebola, id_vars=['Date','Day'])
print(ebola_long.head())

# %%
variable_split= ebola_long.variable.str.split('_')
print(variable_split[:5])

# %%
print(type(variable_split))

# %%
print(type(variable_split[0]))

# %%
status_values= variable_split.str.get(0)
country_values= variable_split.str.get(1)

# %%
print(status_values[:5])

# %%
print(status_values[-5:])

# %%
print(country_values[:5])

# %%
print(country_values[-5:])

# %%
ebola_long['status']= status_valuese
ebola_long['country']= country_values
print(ebola_long.head())

# %%
#163
weather
print(weather.iloc[:5, :])

# %%
weather_melt= pd.melt(wheather,id_vars=['id','year','month','element'],
                      var_name='day', value_name='temp')
print(weather_melt.head())

# %%
weather_tidy= weather_melt.pivot_table(
    index=['id','year','month','day'],
    columns='element',
    values='temp',
    dropna=False
)
print(weather_tidy)

# %%
weather_tidy_flat= weather_tdy.reset_index()

print(weather_tidy_flat.head())

# %%
#166
billboard
billboard_long= pd.melt(billbaoard, id_vars=['year','artist','track','time',
                                             'date.entered'], var_name='week', value_name='rating')
print(billboard_long.shape)

# %%
print(billboard_long.head())

# %%
print(billboard_long[billboard_long.track== 'Loser'].head())

# %%
billboard_songs= billboard_long[['year','artist','track','time']]
print(billboard_songs.shape)

# %%
billboard_songs= billboard_songs.drop_duplicates()
print(billboard_songs.shape)

# %%
billboard_songs['id']=range(len(billboard_songs))
print(billboard_songs.head(n=10))

# %%
billboad_ratings= billboard_long.merge(billboard_songs, on['year','artist','track','time'])
print(billboard_ratings.shape)

# %%
print(billboard_ratings.head())

# %% [markdown]
# # 8장

# %%
import pandas as pd
import seaborn as sns

tips= sns.load_dataset("tips")

# %%
tips['sex_str']=tips['sex'].astype(str)

# %%
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips['total_bill']= tips['total_bill'].astype(str)
print(tips.dtypes)
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips['total_bill']= tips['total_bill'].astype(float)
print(tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips_sub_miss= tips.head(10)
tips_sub_miss.loc[[1,3,5,7], 'total_bill']='missing'
print(tips_sub_miss)
# Out:
#   total_bill   tip     sex smoker  day    time  size sex_str
# 0      16.99  1.01  Female     No  Sun  Dinner     2  Female
# 1    missing  1.66    Male     No  Sun  Dinner     3    Male
# 2      21.01  3.50    Male     No  Sun  Dinner     3    Male
# 3    missing  3.31    Male     No  Sun  Dinner     2    Male
# 4      24.59  3.61  Female     No  Sun  Dinner     4  Female
# 5    missing  4.71    Male     No  Sun  Dinner     4    Male
# 6       8.77  2.00    Male     No  Sun  Dinner     2    Male
# 7    missing  3.12    Male     No  Sun  Dinner     4    Male
# 8      15.04  1.96    Male     No  Sun  Dinner     2    Male
# 9      14.78  3.23    Male     No  Sun  Dinner     2    Male
# /tmp/ipython-input-169582097.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   tips_sub_miss.loc[[1,3,5,7], 'total_bill']='missing'

# %%
print(tips_sub_miss.dtypes)
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='ignore')
print(tips_sub_miss.dtypes)
# Out:
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object
# /tmp/ipython-input-393704038.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='ignore')
# /tmp/ipython-input-393704038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='ignore')

# %%
tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='coerce')
print(tips_sub_miss.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object
# /tmp/ipython-input-2429262248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='coerce')

# %%
tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='coerce', downcast='float')
print(tips_sub_miss.dtypes)
# Out:
# total_bill     float32
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object
# /tmp/ipython-input-835952372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_sub_miss['total_bill']= pd.to_numeric(tips_sub_miss['total_bill'],errors='coerce', downcast='float')

# %%
tips['sex']= tips['sex'].astype('str')
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
#  7   sex_str     244 non-null    object
# dtypes: category(3), float64(2), int64(1), object(2)
# memory usage: 10.8+ KB
# None

# %%
tips['sex']= tips['sex'].astype('category')
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
#  7   sex_str     244 non-null    object
# dtypes: category(4), float64(2), int64(1), object(1)
# memory usage: 9.3+ KB
# None

# %% [markdown]
# # 9장

# %%
word='grail'
sent='a scratch'

print(word[0])
# Out:
# g

# %%
print(sent[0])
# Out:
# a

# %%
print(word[0:3])
# Out:
# gra

# %%
print(sent[-1])
# Out:
# h

# %%
print(sent[-9:-8])
# Out:
# a

# %%
print(sent[0:-8])
# Out:
# a

# %%
print(word[0:3])
# Out:
# gra

# %%
print(word[:3])
# Out:
# gra

# %%
print(sent[2:len(sent)])
# Out:
# scratch

# %%
print(sent[2:])
# Out:
# scratch

# %%
print(sent[ : ])
# Out:
# a scratch

# %%
print(sent[::2])
# Out:
# asrth

# %%
d1='40'
m1="46'"
s1='52.837"'
u1='N'

d2='73℃'
m2="58'"
s2='26.302"'
u2='W'

coords= ' '.join([d1,m1,s1,u1,d2,m2,s2,u2])
print(coords)
# Out:
# 40 46' 52.837" N 73℃ 58' 26.302" W

# %%
multi_str="""Guard: What? Ridden on a horse?
King Arthur: Yes!
Guard: You're using coconuts!
King Arthur: What?
Guard: You've got ... coconut[s] and you're bangin ' 'em together.
"""

print(multi_str)
# Out:
# Guard: What? Ridden on a horse?
# King Arthur: Yes!
# Guard: You're using coconuts!
# King Arthur: What?
# Guard: You've got ... coconut[s] and you're bangin ' 'em together.

# %%
multi_str_split= multi_str.splitlines()
print(multi_str_split)
# Out:
# ['Guard: What? Ridden on a horse?', 'King Arthur: Yes!', "Guard: You're using coconuts!", 'King Arthur: What?', "Guard: You've got ... coconut[s] and you're bangin ' 'em together."]

# %%
guard=multi_str_split[::2]
print(guard)
# Out:
# ['Guard: What? Ridden on a horse?', "Guard: You're using coconuts!", "Guard: You've got ... coconut[s] and you're bangin ' 'em together."]

# %%
guard= multi_str.replace("Guard:","").splitlines()[::2]
print(guard)
# Out:
# [' What? Ridden on a horse?', " You're using coconuts!", " You've got ... coconut[s] and you're bangin ' 'em together."]

# %%
var= ' flesh wound'
s= "It's just a {}!"

print(s.format(var))
# Out:
# It's just a  flesh wound!

# %%
print(s.format('scratch'))
# Out:
# It's just a scratch!

# %%
print('Some digits of pi: {}'.format(3.14159265359))
# Out:
# Some digits of pi: 3.14159265359

# %%
print("In 2005, Lu Chao of China recited {:,} digits i=of pi".format(67890))
# Out:
# In 2005, Lu Chao of China recited 67,890 digits i=of pi

# %%
print("I remember {0:.4} or what Lu Chao recited".format(7/67890))
# Out:
# I remember 0.0001031 or what Lu Chao recited

# %%
print("My ID number is {0:05d}".format(42))
# Out:
# My ID number is 00042

# %%
s='I only know %d digits of pi' %7
print(s)
# Out:
# I only know 7 digits of pi

# %%
print('Some digits of %(cont)s: %(value).2f' % {'cont': 'e', 'value': 2.718})
# Out:
# Some digits of e: 2.72

# %%
import re

tele_num= '1234567890'

# %% [markdown]
# # 10장

# %%
def my_sq(x):
    return x**2

# %%
def my_exp(x,n):
    return x**n

# %%
print(my_sq(4))
# Out:
# 16

# %%
print(my_exp(2,4))
# Out:
# 16

# %%
import pandas as pd

df= pd.DataFrame({'a': [10,20,30], 'b':[20,30,40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
print(df['a']**2)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
sq= df['a'].apply(my_sq)
print(sq)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
ex= df['a'].apply(my_exp, n=2)
print(ex)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
ex= df['a'].apply(my_exp, n=3)
print(ex)
# Out:
# 0     1000
# 1     8000
# 2    27000
# Name: a, dtype: int64

# %%
df= pd.DataFrame({'a': [10,20,30], 'b':[20,30,40]})
print(df)
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def print_me(x):
    print(x)

# %%
print(df.apply(print_me, axis=0))
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# a    None
# b    None
# dtype: object

# %%
print(df['a'])
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64

# %%
print(df['b'])
# Out:
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64

# %%
def avg_3(x, y, z):
    return (x + y + z)/3

# %%
print(df.apply(avg_3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1813414437.py in <cell line: 0>()
# ----> 1 print(df.apply(avg_3))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1061     def apply_standard(self):
#    1062         if self.engine == "python":
# -> 1063             results, res_index = self.apply_series_generator()
#    1064         else:
#    1065             results, res_index = self.apply_series_numba()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#    1079             for i, v in enumerate(series_gen):
#    1080                 # ignore SettingWithCopy here in case the user mutates
# -> 1081                 results[i] = self.func(v, *self.args, **self.kwargs)
#    1082                 if isinstance(results[i], ABCSeries):
#    1083                     # If we have a view on v, we need to make a copy because
#
# TypeError: avg_3() missing 2 required positional arguments: 'y' and 'z'

# %%
def avg_3_apply(col):
    x=col[0]
    y=col[1]
    z=col[2]
    return (x+y+z)/3

print(df.apply(avg_3_apply))
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
def avg_3_apply(col):
    sum=0
    for item in col:
        sum += item
    return sum / df.shape[0]

# %%
def avg_2_apply(row):
    sum=0
    for item in row:
        sum += item
    return sum / df.shape[1]

print(df.apply(avg_2_apply, axis=1))
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
import seaborn as sns

titanic= sns.load_dataset("titanic")

# %%
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
import numpy as np

def count_missing(vec):
    null_vec= pd.isnull(vec)
    null_count= np.sum(null_vec)
    return null_count

# %%
cmis_col= titanic.apply(count_missing)
print(cmis_col)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
def prop_missing(vec):
    num= count_missing(vec)
    dem= vec.size
    return num/dem

# %%
pmis_col= titanic.apply(prop_missing)
print(pmis_col)
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
def prop_complete(vec):
    return 1 - prop_missing(vec)

# %%
cmis_row= titanic.apply(count_missing, axis=1)
pmis_row= titanic.apply(prop_missing, axis=1)
pcom_row= titanic.apply(prop_complete, axis=1)

print(cmis_row.head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# dtype: int64

# %%
print(pmis_row.head())
# Out:
# 0    0.066667
# 1    0.000000
# 2    0.066667
# 3    0.000000
# 4    0.066667
# dtype: float64

# %%
print(pcom_row.head())
# Out:
# 0    0.933333
# 1    1.000000
# 2    0.933333
# 3    1.000000
# 4    0.933333
# dtype: float64

# %%
titanic['num_missing']= titanic.apply(count_missing, axis=1)

print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  num_missing
# 0    man        True  NaN  Southampton    no  False            1
# 1  woman       False    C    Cherbourg   yes  False            0
# 2  woman       False  NaN  Southampton   yes   True            1
# 3  woman       False    C  Southampton   yes  False            0
# 4    man        True  NaN  Southampton    no   True            1

# %%
print(titanic.loc[titanic.num_missing > 1, :].sample(10))
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 650         0       3    male  NaN      0      0   7.8958        S   Third
# 335         0       3    male  NaN      0      0   7.8958        S   Third
# 502         0       3  female  NaN      0      0   7.6292        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 739         0       3    male  NaN      0      0   7.8958        S   Third
# 250         0       3    male  NaN      0      0   7.2500        S   Third
# 277         0       2    male  NaN      0      0   0.0000        S  Second
# 411         0       3    male  NaN      0      0   6.8583        Q   Third
# 760         0       3    male  NaN      0      0  14.5000        S   Third
# 214         0       3    male  NaN      1      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  num_missing
# 650    man        True  NaN  Southampton    no   True            2
# 335    man        True  NaN  Southampton    no   True            2
# 502  woman       False  NaN   Queenstown    no   True            2
# 17     man        True  NaN  Southampton   yes   True            2
# 739    man        True  NaN  Southampton    no   True            2
# 250    man        True  NaN  Southampton    no   True            2
# 277    man        True  NaN  Southampton    no   True            2
# 411    man        True  NaN   Queenstown    no   True            2
# 760    man        True  NaN  Southampton    no   True            2
# 214    man        True  NaN   Queenstown    no  False            2

# %% [markdown]
# # 11장

# %%
import pandas as pd
df

# %%
avg_life_exp_by_year= df.groupby('year').lifeExp.mean()
print(avg_life_exp_by_year)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4254128509.py in <cell line: 0>()
# ----> 1 avg_life_exp_by_year= df.groupby('year').lifeExp.mean()
#       2 print(avg_life_exp_by_year)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'year'

# %%
years= df.year.unique()
print(years)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3184896934.py in <cell line: 0>()
# ----> 1 years= df.year.unique()
#       2 print(years)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %%
y1952= df.loc[df.year == 1952, :]
print(y1952.head())

# %%
y1952_mean= y1952.lifeExp.mean()
print(y1952_mean)

# %%
y1957= df.loc[df.year== 2007, :]
y2007_mean= y2007.lifeExp.mean()
print(y2007_mean)

# %%
df2= pd.DataFrame({"year": [1952,1957,1962,2007],
                   "": [y1952_mean,y1957_mean,y2007_mean]})
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1794422400.py in <cell line: 0>()
#       1 df2= pd.DataFrame({"year": [1952,1957,1962,2007],
# ----> 2                    "": [y1952_mean,y1957_mean,y2007_mean]})
#       3 print(df2)
#
# NameError: name 'y1952_mean' is not defined

# %%
def my_mean(values):
    n= len(values)
        sum = 0
    for value in values:
        sum += value

    return sum/n
# Out:
#   File "/tmp/ipython-input-4111037000.py", line 3
#     sum = 0
#     ^
# IndentationError: unexpected indent

# %%
agg_my_mean= df.groupby('year').lifeExp.agg(my_mean)
print(agg_my_mean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-369241105.py in <cell line: 0>()
# ----> 1 agg_my_mean= df.groupby('year').lifeExp.agg(my_mean)
#       2 print(agg_my_mean)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'year'

# %%
# 223

# %%
import numpy as np
gdf= df.froupby('year').lifeExp.agg([np.count_nonzero, np.mean, np.std])
print(gdf)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3877673853.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 gdf= df.froupby('year').lifeExp.agg([np.count_nonzero, np.mean, np.std])
#       3 print(gdf)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'froupby'

# %%
#224~225

# %%
def my_zscore(x):
    return (x-x.mean()) / x.std()

# %%
transform_z= df.groupby('year').lifeExp.transform(my_zscore)

print(transform_z.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3772625832.py in <cell line: 0>()
# ----> 1 transform_z= df.groupby('year').lifeExp.transform(my_zscore)
#       2
#       3 print(transform_z.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'year'

# %%
print(df.shape)
# Out:
# (3, 2)

# %%
print(transform_z.shape)

# %%
import seaborn as sns
import numpy as np

np.random.seed(42)
tips_10= sns.load_dataset('tips').sample(10)
tips_10.loc[np.random.permutation(tips_10.index)[:4], 'total_bill']= np.NaN
print(tips_10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4097319362.py in <cell line: 0>()
#       4 np.random.seed(42)
#       5 tips_10= sns.load_dataset('tips').sample(10)
# ----> 6 tips_10.loc[np.random.permutation(tips_10.index)[:4], 'total_bill']= np.NaN
#       7 print(tips_10)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     395
#     396         if attr in __expired_attributes__:
# --> 397             raise AttributeError(
#     398                 f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     399                 f"{__expired_attributes__[attr]}"
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %%
count_sex= tips_10.groupby('sex').count()
print(count_sex)
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Male             7    7       7    7     7     7
# Female           3    3       3    3     3     3
# /tmp/ipython-input-1633767297.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   count_sex= tips_10.groupby('sex').count()

# %%
def fill_na_mean(x):
    avg= x.mean()
    return x.fillna(avg)

# %%
total_bill_group_mean= tips_10.groupby('sex').total_bill.transform(fill_na_mean)
tips_10['fill_total_bill']= total_bill_group_mean
print(tips_10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  fill_total_bill
# 24        19.82  3.18    Male     No   Sat  Dinner     2            19.82
# 6          8.77  2.00    Male     No   Sun  Dinner     2             8.77
# 153       24.55  2.00    Male     No   Sun  Dinner     4            24.55
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4            25.89
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2            13.00
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2            17.89
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2            28.44
# 124       12.48  2.52  Female     No  Thur   Lunch     2            12.48
# 9         14.78  3.23    Male     No   Sun  Dinner     2            14.78
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2            15.38
# /tmp/ipython-input-539341435.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_bill_group_mean= tips_10.groupby('sex').total_bill.transform(fill_na_mean)

# %%
tips= sns.load_dataset('tips')
print(tips.shape)
# Out:
# (244, 7)

# %%
print(tips['size'].value_counts())
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
tips_filtered= tips.\
    groupby('size').\
    filter(lambda x: x['size'].count() >= 30)

# %%
print(tips_filtered.shape)
# Out:
# (231, 7)

# %%
print(tips_filtered['size'].value_counts())
# Out:
# size
# 2    156
# 3     38
# 4     37
# Name: count, dtype: int64

# %%
tips_10= sns.load_dataset('tips').sample(10, random_state=42)
print(tips_10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
grouped= tips_10.groupby('sex')
pront(grouped)
# Out:
# /tmp/ipython-input-17627561.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped= tips_10.groupby('sex')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-17627561.py in <cell line: 0>()
#       1 grouped= tips_10.groupby('sex')
# ----> 2 pront(grouped)
#
# NameError: name 'pront' is not defined

# %%
print(grouped.groups)
# Out:
# {'Male': [24, 6, 153, 211, 176, 192, 9], 'Female': [198, 124, 101]}

# %%
avgs= grouped.mean()
print(avgs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-470573417.py in <cell line: 0>()
# ----> 1 avgs= grouped.mean()
#       2 print(avgs)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
# -> 1472                 applied = blk.apply(func)
#    1473                 result_blocks = extend_blocks(applied, result_blocks)
#    1474
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1971         def array_func(values: ArrayLike) -> ArrayLike:
#    1972             try:
# -> 1973                 result = self._grouper._cython_operation(
#    1974                     "aggregate",
#    1975                     values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829         ids, _, _ = self.group_info
#     830         ngroups = self.ngroups
# --> 831         return cy_op.cython_operation(
#     832             values=values,
#     833             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     539         if not isinstance(values, np.ndarray):
#     540             # i.e. ExtensionArray
# --> 541             return values._groupby_op(
#     542                 how=self.how,
#     543                 has_dropped_na=self.has_dropped_na,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2738             if kind == "transform":
#    2739                 raise TypeError(f"{dtype} type does not support {how} operations")
# -> 2740             raise TypeError(f"{dtype} dtype does not support aggregation '{how}'")
#    2741
#    2742         result_mask = None
#
# TypeError: category dtype does not support aggregation 'mean'

# %%
print(tips_10.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
female= grouped.get_group('Female')
print(female)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
for sex_group in grouped:
    print(sex_group)
# Out:
# ('Male',      total_bill   tip   sex smoker   day    time  size
# 24        19.82  3.18  Male     No   Sat  Dinner     2
# 6          8.77  2.00  Male     No   Sun  Dinner     2
# 153       24.55  2.00  Male     No   Sun  Dinner     4
# 211       25.89  5.16  Male    Yes   Sat  Dinner     4
# 176       17.89  2.00  Male    Yes   Sun  Dinner     2
# 192       28.44  2.56  Male    Yes  Thur   Lunch     2
# 9         14.78  3.23  Male     No   Sun  Dinner     2)
# ('Female',      total_bill   tip     sex smoker   day    time  size
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2)

# %%
for sex_group in grouped:
    print(sex_group)
# Out:
# ('Male',      total_bill   tip   sex smoker   day    time  size
# 24        19.82  3.18  Male     No   Sat  Dinner     2
# 6          8.77  2.00  Male     No   Sun  Dinner     2
# 153       24.55  2.00  Male     No   Sun  Dinner     4
# 211       25.89  5.16  Male    Yes   Sat  Dinner     4
# 176       17.89  2.00  Male    Yes   Sun  Dinner     2
# 192       28.44  2.56  Male    Yes  Thur   Lunch     2
# 9         14.78  3.23  Male     No   Sun  Dinner     2)
# ('Female',      total_bill   tip     sex smoker   day    time  size
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2)

# %%
for sex_group in grouped:
    print('the type is : {}\n'.format(type(sex_group)))
    print('the length is : {}\n'.format(len(sex_group)))

    first_element= sex_group[0]

    print('the first element is: {}\n'.format(first_element))
    print('it has a type of: {}\n'.format(type(sex_group[0])))

    second_element= sex_group[1]
    print('the second element is:\n{}\n'.formet(second_element))
    print('it has a type of: {}\n'.format(type(second_element)))

    print('what we have: ')
    print(sex_group)

    break
# Out:
# the type is : <class 'tuple'>
#
# the length is : 2
#
# the first element is: Male
#
# it has a type of: <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3135761475.py in <cell line: 0>()
#       9
#      10     second_element= sex_group[1]
# ---> 11     print('the second element is:\n{}\n'.formet(second_element))
#      12     print('it has a type of: {}\n'.format(type(second_element)))
#      13
#
# AttributeError: 'str' object has no attribute 'formet'

# %%
bill_sex_time= tips_10.groupby(['sex','time'])
group_avg= bill_sex_time.mean()

print(group_avg)
# Out:
# /tmp/ipython-input-4229177286.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill_sex_time= tips_10.groupby(['sex','time'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4229177286.py in <cell line: 0>()
#       1 bill_sex_time= tips_10.groupby(['sex','time'])
# ----> 2 group_avg= bill_sex_time.mean()
#       3
#       4 print(group_avg)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
# -> 1472                 applied = blk.apply(func)
#    1473                 result_blocks = extend_blocks(applied, result_blocks)
#    1474
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1971         def array_func(values: ArrayLike) -> ArrayLike:
#    1972             try:
# -> 1973                 result = self._grouper._cython_operation(
#    1974                     "aggregate",
#    1975                     values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829         ids, _, _ = self.group_info
#     830         ngroups = self.ngroups
# --> 831         return cy_op.cython_operation(
#     832             values=values,
#     833             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     539         if not isinstance(values, np.ndarray):
#     540             # i.e. ExtensionArray
# --> 541             return values._groupby_op(
#     542                 how=self.how,
#     543                 has_dropped_na=self.has_dropped_na,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2738             if kind == "transform":
#    2739                 raise TypeError(f"{dtype} type does not support {how} operations")
# -> 2740             raise TypeError(f"{dtype} dtype does not support aggregation '{how}'")
#    2741
#    2742         result_mask = None
#
# TypeError: category dtype does not support aggregation 'mean'

# %%
print(type(group_avg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-900247622.py in <cell line: 0>()
# ----> 1 print(type(group_avg))
#
# NameError: name 'group_avg' is not defined

# %%
print(group_avg.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3420986095.py in <cell line: 0>()
# ----> 1 print(group_avg.columns)
#
# NameError: name 'group_avg' is not defined

# %%
print(group_avg.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3319591388.py in <cell line: 0>()
# ----> 1 print(group_avg.index)
#
# NameError: name 'group_avg' is not defined

# %%
group_method= tips_10.groupby(['sex, 'time]).mean().reset_index()
print(group_method)
# Out:
#   File "/tmp/ipython-input-708686570.py", line 1
#     group_method= tips_10.groupby(['sex, 'time]).mean().reset_index()
#                                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
grouop_param= tips_10.groupby(['sex','time'], as_index=Female).mean()
print(group_param)

# %% [markdown]
# #12장

# %%
from datetime import datetime

# %%
now1= datetime.now()
print(now1)
# Out:
# 2025-08-31 17:12:33.532602

# %%
now2= datetime.today()
print(now2)
# Out:
# 2025-08-31 17:12:55.907993

# %%
t1= datetime.now()
t2= datetime(1970, 1, 1)
t3= datetime(1970, 12, 12, 13, 24, 34)

print(t1)
print(t2)
print(t3)
# Out:
# 2025-08-31 17:14:11.134431
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %%
diff1= t1 - t2

print(diff1)
print(type(diff1))
# Out:
# 20331 days, 17:14:11.134431
# <class 'datetime.timedelta'>

# %%
diff2= t2 - t1

print(diff2)
print(type(diff2))
# Out:
# -20332 days, 6:45:48.865569
# <class 'datetime.timedelta'>

# %%
#243~255

# %%
import mathplotlib.pyplot as plt

fig, ax= plt.subplots()

ax= closing_year.plot()

plt.show()

fig, ax= plt.subplots()
ax= closing_year_q.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-53482572.py in <cell line: 0>()
# ----> 1 import mathplotlib.pyplot as plt
#       2
#       3 fig, ax= plt.subplots()
#       4
#       5 ax= closing_year.plot()
#
# ModuleNotFoundError: No module named 'mathplotlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (5.4.0)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pandas-datareader) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas-datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pandas-datareader) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.17.0)

# %%
#256~263

# %%
import matplotlib.pyplot as plt

ebola.index= ebola['Date']

fig, ax=plt.subplots()
ax=ebola.iloc[0:, 1:].plot(ax=ax)

ax.legend(fontsize=7, loc=2, borderaxespad=0.)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4005913526.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 ebola.index= ebola['Date']
#       4
#       5 fig, ax=plt.subplots()
#
# NameError: name 'ebola' is not defined

# %%
# 265~271
